# %% [markdown]
# # Predicting pit stop from stint number, tyre, and other data
#
# This is my attempt at predicting whether a driver will need to make a pit stop in the next lap for the "Predicting F1 Pit Stops" playground competition on Kaggle (Yao Yan, Walter Reade, Elizabeth Park. Predicting F1 Pit Stops. https://kaggle.com/competitions/playground-series-s6e5, 2026. Kaggle.) This competition uses synthetic data inspired by the "F1 Strategy Dataset" at https://www.kaggle.com/datasets/aadigupta1601/f1-strategy-dataset-pit-stop-prediction/data. First let's take a look at the data.

# %%
from setup import *
source = pd.read_csv('../data/train.csv')
source.head()
# Out:
#    id Driver Compound                   Race  Year  PitStop  LapNumber  Stint  \
# 0   0   D109     HARD    Canadian Grand Prix  2022        0         50      2
# 1   1   D086     HARD       Dutch Grand Prix  2025        1         27      2
# 2   2    ZON     HARD    Austrian Grand Prix  2022        0         59      3
# 3   3    SPE   MEDIUM     Pre-Season Testing  2023        0          2      1
# 4   4   D019     HARD  Azerbaijan Grand Prix  2022        1         26      3
#
#    TyreLife  Position  LapTime (s)  LapTime_Delta  Cumulative_Degradation  \
# 0      39.0         8       78.491         -7.564                  21.019
# 1       7.0         4       75.095        -32.617                -223.207
# 2      22.0        13       70.945         -7.540                -100.529
# 3       2.0         7       94.361         -7.324                  -7.324
# 4       6.0         2      107.878          8.965                 -14.139
#
#    RaceProgress  Position_Change  PitNextLap
# ...

# %% [markdown]
# ## First take
# ### Low-hanging fruit
# TyreLife should be strongly correlated with the target variable. Compound may directly affect the TyreLife value at which a pit stop is warranted. Cumulative_Degradation should similarly have a strong relationship to the target. PitStop is presumably negatively correlated with PitNextLap.
# ### Driver strategy
# Whether to make a pit stop has much to do with the driver's strategy, and there may be traces of this in the data. For instance, if most of the drivers are going slow, a pit stop costs less. So a feature accumulating LapTimes in the same lap for different drivers might tell us something about the likelihood of a driver making a pit stop. The driver's own laptime_delta might also be somewhat indicative of favorable conditions for a pitstop.
# ### Environment
# Important information like the temperature is missing. Perhaps this information is recoverable in Year and Race.

# %%
# First, let's clean it up a little so we can look at relationships.
driver_enc = OrdinalEncoder(categories='auto')
source["Driver_encoded"] = driver_enc.fit_transform(source[["Driver"]])
race_enc = OrdinalEncoder(categories='auto')
source["Race_encoded"] = race_enc.fit_transform(source[["Race"]])
compound_enc = OneHotEncoder(handle_unknown='ignore', categories='auto')
compound_cols = compound_enc.fit_transform(source[["Compound"]])
compound_cols = pd.DataFrame.sparse.from_spmatrix(compound_cols)
compound_headers = np.sort(source["Compound"].unique())

compound_cols = compound_cols.rename(columns={
    0: compound_headers[0],
    1: compound_headers[1],
    2: compound_headers[2],
    3: compound_headers[3],
    4: compound_headers[4]
})
F1_clean = pd.concat([source, compound_cols], axis=1)
F1_clean = F1_clean.drop(columns = ["Race", "Driver","Compound"])

# %%
# Let's make a heatmap showing correlations.
plt.figure(figsize=(16, 6))
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(F1_clean.corr(), cmap="coolwarm", vmin=-1, vmax=1, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Tyrelife has a 0.27 correlation with the target. Hard and Medium are correlated at 0.26 and -0.24 with the target. I would have expected Hard to have a negative correlation, since it is more durable than the other types. It would be interesting to examine this in the natural data set. Cumulative_Degeneration is slightly mildly correlated with the target, another surprise.

# %%
ax = sns.kdeplot(x=F1_clean["LapNumber"], y=F1_clean["Stint"])
ax.set_xlabel("Lap number")
ax.set_ylabel("Stint")
plt.show()

# %%
# Add Mean_lap_time to see if the strategy desribed above affects
# drivers' pit stops.
F1_clean["Mean_lap_time"] = F1_clean.groupby(["Race_encoded", "Year", "LapNumber"])["LapTime (s)"].transform("mean")
F1_clean.head()
# Out:
#    id  Year  PitStop  LapNumber  Stint  TyreLife  Position  LapTime (s)  \
# 0   0  2022        0         50      2      39.0         8       78.491
# 1   1  2025        1         27      2       7.0         4       75.095
# 2   2  2022        0         59      3      22.0        13       70.945
# 3   3  2023        0          2      1       2.0         7       94.361
# 4   4  2022        1         26      3       6.0         2      107.878
#
#    LapTime_Delta  Cumulative_Degradation  ...  Position_Change  PitNextLap  \
# 0         -7.564                  21.019  ...              5.0         1.0
# 1        -32.617                -223.207  ...             -3.0         0.0
# 2         -7.540                -100.529  ...              3.0         1.0
# 3         -7.324                  -7.324  ...              0.0         0.0
# 4          8.965                 -14.139  ...              3.0         0.0
#
#    Driver_encoded  Race_encoded  HARD  INTERMEDIATE  MEDIUM  SOFT  WET  \
# ...

# %%
F1_clean["PitNextLap"].corr(F1_clean["Mean_lap_time"])
# Out:
# np.float64(-0.05279977131505487)

# %%
source['LapNumber'].describe()
# Out:
# count    439140.000000
# mean         23.105909
# std          16.958261
# min           1.000000
# 25%           9.000000
# 50%          19.000000
# 75%          36.000000
# max          78.000000
# Name: LapNumber, dtype: float64

# %%
source['LapNumber'].hist()
# Out:
# <Axes: >

# %%
source.plot(kind='line', x='Stint', y='LapNumber')
# Out:
# <Axes: xlabel='Stint'>

# %% [markdown]
# This is interesting. There seems to be a correlation between stint and laps, but this tangle of lines is strange.

# %%
source['LapNumber'].corr(source['Stint'])
# Out:
# np.float64(0.7243895409301391)

# %% [markdown]
# There is definitely a strong correlation.

# %%
source[(source['Driver']=='D109') & (source['Race'] == 'Canadian Grand Prix') & (source['Year'] == 2022)]
# Out:
#             id Driver Compound                 Race  Year  PitStop  LapNumber  \
# 0            0   D109     HARD  Canadian Grand Prix  2022        0         50
# 55127    55127   D109     HARD  Canadian Grand Prix  2022        1         26
# 129360  129360   D109   MEDIUM  Canadian Grand Prix  2022        0          2
# 173097  173097   D109   MEDIUM  Canadian Grand Prix  2022        0         15
# 223396  223396   D109     HARD  Canadian Grand Prix  2022        0         16
# 225817  225817   D109   MEDIUM  Canadian Grand Prix  2022        1          5
# 245616  245616   D109   MEDIUM  Canadian Grand Prix  2022        0         12
# 293037  293037   D109     HARD  Canadian Grand Prix  2022        0         21
# 316356  316356   D109     HARD  Canadian Grand Prix  2022        0         39
# 328772  328772   D109     HARD  Canadian Grand Prix  2022        0         34
# 348645  348645   D109   MEDIUM  Canadian Grand Prix  2022        0          4
# ...

# %% [markdown]
# In stint 1, driver D109 had Medium tires, and on stint 2, driver D109 had Hard tires.

# %%
source['PitStop'].describe()
# Out:
# count    439140.000000
# mean          0.136118
# std           0.342915
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: PitStop, dtype: float64

# %%
source['LapNumber'].plot.density()
# Out:
# <Axes: ylabel='Density'>
